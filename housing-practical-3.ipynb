# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# EDA
import matplotlib.pyplot as plt
import seaborn as sns

# preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer

#models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_csv("../input/california-housing-prices/housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # Handling Categorical Variables

# %%
cat_cols = [col for col in df.columns if df[col].dtype == 'object']
cat_cols
# Out:
# ['ocean_proximity']

# %%
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()

df.loc[:, cat_cols] = lb.fit_transform(np.array(df.loc[:, cat_cols]).reshape(-1, ))

# %% [markdown]
# # Handling Missing Values

# %%
import missingno as msno

msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df, color = 'blue')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Above visualizations implies features total_bedrooms has missing values which we need to handle

# %% [markdown]
# Will use knn imputer to impute missing values

# %%
from sklearn.impute import KNNImputer

knn = KNNImputer(n_neighbors = 3)

# %%
knn_imputer = KNNImputer(n_neighbors = 3)

df_pre1 = df.copy()

X = np.round(knn_imputer.fit_transform(df_pre1))
df_pre1 = pd.DataFrame(X, columns = df_pre1.columns)

# %%
df_pre1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  float64
# dtypes: float64(10)
# memory usage: 1.6 MB

# %%
X = np.array(df_pre1.drop('median_house_value', axis = 1))
y = np.array(df_pre1['median_house_value'])

# %% [markdown]
# # Feature Scaling

# %%
# from sklearn.preprocessing import StandardScaler

# sc = StandardScaler()

# X = sc.fit_transform(X)

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer()

X = pt.fit_transform(X)

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 11)

# %%
mse = []
mae = []
rmse = []

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics


lr = LinearRegression()

lr.fit(X_train, y_train)

print("Mean Squared Error For Linear Regression Model is : {}".format(metrics.mean_squared_error(y_test, lr.predict(X_test))))
mse.append(metrics.mean_squared_error(y_test, lr.predict(X_test)))
print("Root Mean Square Error For Linear Regression Model is : {}".format(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test)))))
rmse.append(np.sqrt(metrics.mean_squared_error(y_test, lr.predict(X_test))))
print("Mean Absolute Erorr For Linear Regression Model is : {}".format(metrics.mean_absolute_error(y_test, lr.predict(X_test))))
mae.append(metrics.mean_absolute_error(y_test, lr.predict(X_test)))
# Out:
# Mean Squared Error For Linear Regression Model is : 5313372397.160803
# Root Mean Square Error For Linear Regression Model is : 72892.88303504535
# Mean Absolute Erorr For Linear Regression Model is : 55914.02827261214

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVR
from sklearn import metrics


svr = SVR()

svr.fit(X_train, y_train)

print("Mean Squared Error For Support Vector Machine Model is : {}".format(metrics.mean_squared_error(y_test, svr.predict(X_test))))
print("Root Mean Square Error For Support Vector Machine Model is : {}".format(np.sqrt(metrics.mean_squared_error(y_test, svr.predict(X_test)))))
print("Mean Absolute Erorr For Support Vector Machine Model is : {}".format(metrics.mean_absolute_error(y_test, svr.predict(X_test))))



mse.append(metrics.mean_squared_error(y_test, svr.predict(X_test)))
rmse.append(np.sqrt(metrics.mean_squared_error(y_test, svr.predict(X_test))))
mae.append(metrics.mean_absolute_error(y_test, svr.predict(X_test)))
# Out:
# Mean Squared Error For Support Vector Machine Model is : 14386136929.423092
# Root Mean Square Error For Support Vector Machine Model is : 119942.223296982
# Mean Absolute Erorr For Support Vector Machine Model is : 89166.95973903831

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics


dt = DecisionTreeRegressor()

dt.fit(X_train, y_train)

print("Mean Squared Error For Decision Tree Model is : {}".format(metrics.mean_squared_error(y_test, dt.predict(X_test))))
print("Root Mean Square Error For Decision Tree Model is : {}".format(np.sqrt(metrics.mean_squared_error(y_test, dt.predict(X_test)))))
print("Mean Absolute Erorr For Decision Tree Model is : {}".format(metrics.mean_absolute_error(y_test, dt.predict(X_test))))



mse.append(metrics.mean_squared_error(y_test, dt.predict(X_test)))
rmse.append(np.sqrt(metrics.mean_squared_error(y_test,dt.predict(X_test))))
mae.append(metrics.mean_absolute_error(y_test, dt.predict(X_test)))
# Out:
# Mean Squared Error For Decision Tree Model is : 6480405325.820251
# Root Mean Square Error For Decision Tree Model is : 80500.96475086651
# Mean Absolute Erorr For Decision Tree Model is : 54605.18071705427

# %% [markdown]
# # Bayesian Regression

# %%
from sklearn.linear_model import BayesianRidge
from sklearn import metrics


bs = BayesianRidge()

bs.fit(X_train, y_train)

print("Mean Squared Error For Bayesian Regression Model is : {}".format(metrics.mean_squared_error(y_test, bs.predict(X_test))))
print("Root Mean Square Error For Bayesian Regression Model is : {}".format(np.sqrt(metrics.mean_squared_error(y_test, bs.predict(X_test)))))
print("Mean Absolute Erorr For Bayesian Regression Model is : {}".format(metrics.mean_absolute_error(y_test, bs.predict(X_test))))



mse.append(metrics.mean_squared_error(y_test, bs.predict(X_test)))
rmse.append(np.sqrt(metrics.mean_squared_error(y_test, bs.predict(X_test))))
mae.append(metrics.mean_absolute_error(y_test, bs.predict(X_test)))
# Out:
# Mean Squared Error For Bayesian Regression Model is : 5932673939.558081
# Root Mean Square Error For Bayesian Regression Model is : 77023.85305577799
# Mean Absolute Erorr For Bayesian Regression Model is : 59412.11953502398

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics


rf = RandomForestRegressor()

rf.fit(X_train, y_train)

print("Mean Squared Error For Random Forest Model is : {}".format(metrics.mean_squared_error(y_test, rf.predict(X_test))))
print("Root Mean Square Error For Random Forest Model is : {}".format(np.sqrt(metrics.mean_squared_error(y_test, rf.predict(X_test)))))
print("Mean Absolute Erorr For Random Forest Model is : {}".format(metrics.mean_absolute_error(y_test, rf.predict(X_test))))



mse.append(metrics.mean_squared_error(y_test, rf.predict(X_test)))
rmse.append(np.sqrt(metrics.mean_squared_error(y_test, rf.predict(X_test))))
mae.append(metrics.mean_absolute_error(y_test, rf.predict(X_test)))
# Out:
# Mean Squared Error For Random Forest Model is : 3662337596.8549967
# Root Mean Square Error For Random Forest Model is : 60517.25040725988
# Mean Absolute Erorr For Random Forest Model is : 41732.959014050386

# %% [markdown]
# # Plots

# %%
models = ["Linear Regression", "Support Vector Regression", "Decision Tree Regression", "Bayesian Regression", "Random Forest Regressor"]

# %%
x_mse = np.arange(0, len(mse))
x_rmse = np.arange(0, len(rmse))
x_mae = np.arange(0, len(mae))

# %%
plt.figure(figsize=(17,6))
plt.yticks(fontsize=15)
plt.bar(x_mse , mse,align='center')
plt.xticks(x_mse, models,rotation=60,fontsize=15)
plt.grid(True , linestyle = '--',linewidth = 0.3)
plt.xlabel("Models",fontsize=15)
plt.ylabel('Mean Squared Errors',fontsize=15)
plt.title("Mean Squared Errors of Different Models",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(17,6))
plt.yticks(fontsize=15)
plt.bar(x_rmse , rmse,align='center')
plt.xticks(x_rmse, models,rotation=60,fontsize=15)
plt.grid(True , linestyle = '--',linewidth = 0.3)
plt.xlabel("Models",fontsize=15)
plt.ylabel('Root Mean Squared Errors',fontsize=15)
plt.title("Root Mean Squared Errors of Different Models",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(17,6))
plt.yticks(fontsize=15)
plt.bar(x_mae , mae,align='center')
plt.xticks(x_rmse, models,rotation=60,fontsize=15)
plt.grid(True , linestyle = '--',linewidth = 0.3)
plt.xlabel("Models",fontsize=15)
plt.ylabel('Mean Absolute Errors',fontsize=15)
plt.title("Mean Absolute Errors of Different Models",fontsize=20)
plt.show()

# %% [markdown]
# <h3 style = "text-align:center">Table of Comparison of Different Regression Models on Housing Data</h3>
#
# <table>
#   <tr>
#     <th>Errors</th>
#     <th>Linear Regression</th>
#     <th>Support Vector Regression</th>
#     <th>Decision Tree Regression</th>
#     <th>Bayesian Regression</th>
#     <th>Random Forest Regression</th>
#
#   </tr>
#   <tr>
#     <td>Mean Squared </td>
#       <td> 5313372397.160803 </td>
#       <td> 14386136929.423092 </td>
#       <td> 6427763316.611918 </td>
#       <td> 5932673939.558081 </td>
#       <td> 3663745160.6476661 </td>
#   </tr>
#   <tr>
#     <td>Root Mean Square </td>
#       <td> 72892.88303504535 </td>
#       <td> 119942.223296982 </td>
#       <td> 80173.3329518732 </td>
#       <td> 77023.85305577799 </td>
#       <td> 60528.87873278065 </td>
#   </tr>
#   <tr>
#     <td>Mean Absolute </td>
#       <td> 55914.02827261214 </td>
#       <td> 89166.95973903831 </td>
#       <td> 54384.126453488374 </td>
#       <td> 59412.11953502398 </td>
#       <td> 41711.06853682171 </td>
#   </tr>
#
# </table>
